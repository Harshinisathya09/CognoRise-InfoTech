# %% [markdown]
# # Wine Quality analysis #

# %% [markdown]
# ## Import packages ##

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
wine=pd.read_csv(r"winequality-red.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0               7.4             0.700         0.00             1.9      0.076  \
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine.shape
# Out:
# (1599, 12)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar
# count    1599.000000       1599.000000  1599.000000     1599.000000  \
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density
# count  1599.000000          1599.000000           1599.000000  1599.000000  \
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ## Data distribution

# %%
plt.figure(figsize=(10,6))
plt.title("Data distribution")
sns.histplot(data=wine)
# Out:
# <Axes: title={'center': 'Data distribution'}, ylabel='Count'>

# %%
wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.histplot(x='fixed acidity',data=wine,kde=True)
plt.title("Distribution of fixed acidity")
plt.xlabel("Fixed acidity")
# Out:
# Text(0.5, 0, 'Fixed acidity')

# %%
sns.histplot(x='volatile acidity',data=wine,kde=True)
plt.title("Distribution of volatile acidity")
plt.xlabel("Volatile acidity")
# Out:
# Text(0.5, 0, 'Volatile acidity')

# %%
sns.histplot(x='citric acid',data=wine,kde=True)
plt.title("Distribution of citric acid")
plt.xlabel("Citric acidity")
# Out:
# Text(0.5, 0, 'Citric acidity')

# %%
sns.histplot(x='residual sugar',data=wine,kde=True)
plt.title("Distribution of residual sugar")
plt.xlabel("Residual sugar")
# Out:
# Text(0.5, 0, 'Residual sugar')

# %%
sns.histplot(x='chlorides',data=wine,kde=True)
plt.title("Distribution of Chloride")
plt.xlabel("Chlorides")
# Out:
# Text(0.5, 0, 'Chlorides')

# %%
sns.histplot(x='free sulfur dioxide',data=wine,kde=True)
plt.title("Distribution of free sulfur dioxide")
plt.xlabel("Free sulfur dioxide")
# Out:
# Text(0.5, 0, 'Free sulfur dioxide')

# %%
sns.histplot(x='total sulfur dioxide',data=wine,kde=True)
plt.title("Distribution of Total sulfur dioxide")
plt.xlabel("Total sulfur dioxide")
# Out:
# Text(0.5, 0, 'Total sulfur dioxide')

# %%
sns.histplot(x='density',data=wine,kde=True)
plt.title("Distribution of Density")
plt.xlabel("Density")
# Out:
# Text(0.5, 0, 'Density')

# %%
sns.histplot(x='pH',data=wine,kde=True)
plt.title("Distribution of pH")
plt.xlabel("pH")
# Out:
# Text(0.5, 0, 'pH')

# %%
sns.histplot(x='sulphates',data=wine,kde=True)
plt.title("Distribution of Sulphates")
plt.xlabel("Sulphates")
# Out:
# Text(0.5, 0, 'Sulphates')

# %%
sns.histplot(x='alcohol',data=wine,kde=True)
plt.title("Distribution of Alcohol")
plt.xlabel("Alcohol")
# Out:
# Text(0.5, 0, 'Alcohol')

# %%
sns.histplot(x='quality',data=wine,kde=True)
plt.title("Distribution of Quality")
plt.xlabel("Quality")
# Out:
# Text(0.5, 0, 'Quality')

# %%
plt.figure(figsize=(10,10))
sns.heatmap(wine.corr(),annot=True,linewidth=0.5,center=0,cmap='coolwarm')
plt.show()

# %%
sns.boxplot(x='quality',y='alcohol',data=wine,palette='GnBu_d')
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.boxplot(x='quality',y='pH',data=wine,palette='GnBu_d')
plt.title("Boxplot of Quality and pH")
plt.show()

# %%
sns.scatterplot(wine, x="alcohol", y="citric acid", hue="quality", palette="YlOrBr")
# Out:
# <Axes: xlabel='alcohol', ylabel='citric acid'>
